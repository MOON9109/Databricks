# %%
print('hello world')

# %%
# %sql

select "hello world from SQL"

# %%
# %run ./includes/Setup

# %%
print(full_name)

# %%
# %fs ls '/databricks-datasets'

# %%
dbutils.help()

# %%
dbutils.fs.help()

# %%
files=dbutils.fs.ls('/databricks-datasets')
print(files)

# %%
display(files)
